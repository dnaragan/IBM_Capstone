# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
# !conda install lxml --yes

# %%
df = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")[0]
df
# Out:
#     Postal code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# ...

# %%
df['Borough'].replace('Not assigned', np.nan, inplace=True)
df.dropna(subset=['Borough'], inplace=True, how='all')
df
# Out:
#     Postal code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# 5                    Lawrence Manor / Lawrence Heights
# 6         Queen's Park / Ontario Provincial Government
# ..                                                 ...
# 160    The Kingsway / Montgomery Road / Old Mill North
# 165                               Church and Wellesley
# ...

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part 2

# %%
import geocoder

# %%
# initialize your variable to None
lat_lng_coords = None

# loop until you get the coordinates
while(lat_lng_coords is None):
  g = geocoder.google('{}, Toronto, Ontario'.format('M5G'))
  lat_lng_coords = g.latlng

latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0eff9a17e61a> in <module>
#       4 # loop until you get the coordinates
#       5 while(lat_lng_coords is None):
# ----> 6   g = geocoder.google('{}, Toronto, Ontario'.format('M5G'))
#       7   lat_lng_coords = g.latlng
#       8
#
# ~/anaconda3/envs/spyder/lib/python3.8/site-packages/geocoder/api.py in google(location, **kwargs)
#     230         > elevation
#     231     """
# --> 232     return get(location, provider='google', **kwargs)
#     233
#     234
#
# ~/anaconda3/envs/spyder/lib/python3.8/site-packages/geocoder/api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# ...

# %%
df_postalcodes_latlong = pd.read_csv('Geospatial_Coordinates.csv')

# %%
df.merge(df_postalcodes_latlong, left_on='Postal code', right_on='Postal Code', how='left')
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood Postal Code   Latitude  \
# 0                                            Parkwoods         M3A  43.753259
# 1                                     Victoria Village         M4A  43.725882
# 2                           Regent Park / Harbourfront         M5A  43.654260
# 3                    Lawrence Manor / Lawrence Heights         M6A  43.718518
# 4         Queen's Park / Ontario Provincial Government         M7A  43.662301
# ..                                                 ...         ...        ...
# ...

# %% [markdown]
# # Part 3

# %%
# ! conda install geopy -c conda-forge --yes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Postal Code  103 non-null    object
#  1   Latitude     103 non-null    float64
#  2   Longitude    103 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB

# %%
df = df[df.Borough.str.contains('Toronto',case=False)]
# [i for i in df['Borough'] if 'Toronto' in i]

# %%
df
# Out:
#     Postal code           Borough  \
# 4           M5A  Downtown Toronto
# 6           M7A  Downtown Toronto
# 13          M5B  Downtown Toronto
# 22          M5C  Downtown Toronto
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# 49          M5H  Downtown Toronto
# 50          M6H      West Toronto
# 58          M5J  Downtown Toronto
# 59          M6J      West Toronto
# 66          M4K      East Toronto
# 67          M5K  Downtown Toronto
# 68          M6K      West Toronto
# 75          M4L      East Toronto
# 76          M5L  Downtown Toronto
# 84          M4M      East Toronto
# 93          M4N   Central Toronto
# 94          M5N   Central Toronto
# 102         M4P   Central Toronto
# 103         M5P   Central Toronto
# 104         M6P      West Toronto
# 111         M4R   Central Toronto
# 112         M5R   Central Toronto
# 113         M6R      West Toronto
# ...
